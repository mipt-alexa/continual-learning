# %%
from visualize import plot
from os import listdir
import json

# %%
[dir for dir in listdir("../results") if "replay_vit" in dir]
# Out:
# ['cil_replay_vit_adam_5e-05_0e+00_20.json',
#  'cil_replay_vit_adam_1e-04_0e+00_20.json',
#  'cil_replay_vit_adam_1e-05_0e+00_20.json']

# %%
[dir for dir in listdir("../results") if "replay_True" in dir]
# Out:
# ['cil_replay_True_vit_adam_1e-4_0e+0_15.json',
#  'cil_replay_True_vit_adam_1e-5_0e+0_15.json',
#  'cil_replay_True_resnet_adam_1e-5_0e+0_10.json',
#  'cil_replay_True_resnet_adam_1e-4_0e+0_10.json',
#  'cil_replay_True_resnet_adam_1e-5_0e+0_15.json',
#  'cil_replay_True_resnet_adam_1e-4_0e+0_15.json',
#  'cil_replay_True_resnet_adam_1e-5_1e-5_15.json',
#  'cil_replay_True_resnet_adam_1e-4_1e-5_15.json',
#  'cil_replay_True_vit_adam_1e-4_1e-5_15.json',
#  'cil_replay_True_vit_adam_1e-5_1e-5_15.json',
#  'cil_replay_True_resnet_adam_1e-3_0e+0_1.json']

# %%
[dir for dir in listdir("../results") if "cil_True" in dir]
# Out:
# ['cil_True_vit_adam_1e-3_0e+0_1.json']

# %%
[plot(dir) for dir in listdir("../results") if "replay_True_vit" in dir]
# Out:
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-4
# weight_decay: 0e+0
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-5
# weight_decay: 0e+0
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-4
# weight_decay: 1e-5
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-5
# weight_decay: 1e-5
# num_epochs: 15
# [None, None, None, None]

# %%
[plot(dir) for dir in listdir("../results") if "replay_True_resnet" in dir]
# Out:
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-5
# weight_decay: 0e+0
# num_epochs: 10
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-4
# weight_decay: 0e+0
# num_epochs: 10
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-5
# weight_decay: 0e+0
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-4
# weight_decay: 0e+0
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-5
# weight_decay: 1e-5
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-4
# weight_decay: 1e-5
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-3
# weight_decay: 0e+0
# num_epochs: 1
# [None, None, None, None, None, None, None]

# %%
[plot(dir) for dir in listdir("../results") if "True" in dir]
# Out:
# mode: cil
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-3
# weight_decay: 0e+0
# num_epochs: 1
# [None]

# %%
[dir for dir in listdir("../results") if "cil_replay_True" in dir]
# Out:
# ['cil_replay_True_vit_adam_1e-4_0e+0_15.json',
#  'cil_replay_True_vit_adam_1e-5_0e+0_15.json',
#  'cil_replay_True_resnet_adam_1e-5_0e+0_10.json',
#  'cil_replay_True_resnet_adam_1e-4_0e+0_10.json',
#  'cil_replay_True_vit_adam_1e-4_1e-5_15.json',
#  'cil_replay_True_vit_adam_1e-5_1e-5_15.json',
#  'cil_replay_True_resnet_adam_1e-3_0e+0_1.json']

# %%
plot('cil_replay_True_vit_adam_1e-4_0e+0_15.json') 
plot('cil_replay_True_vit_adam_1e-5_0e+0_15.json')
# Out:
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-4
# weight_decay: 0e+0
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-5
# weight_decay: 0e+0
# num_epochs: 15

# %%
plot( 'cil_replay_True_resnet_adam_1e-5_0e+0_10.json')
plot( 'cil_replay_True_resnet_adam_1e-4_0e+0_10.json')
# Out:
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-5
# weight_decay: 0e+0
# num_epochs: 10
# mode: cil_replay
# freeze: True
# model: resnet
# optimizer: adam
# lr: 1e-4
# weight_decay: 0e+0
# num_epochs: 10

# %%
plot('cil_replay_True_vit_adam_1e-4_1e-5_15.json') 
plot('cil_replay_True_vit_adam_1e-5_1e-5_15.json')
# Out:
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-4
# weight_decay: 1e-5
# num_epochs: 15
# mode: cil_replay
# freeze: True
# model: vit
# optimizer: adam
# lr: 1e-5
# weight_decay: 1e-5
# num_epochs: 15

# %%
[plot(dir) for dir in listdir("../results") if "cil_replay" in dir]
# Out:
# mode: cil_replay
# model: vit
# optimizer: adam
# lr: 5e-05
# weight_decay: 0e+00
# num_epochs: 20
# ...
